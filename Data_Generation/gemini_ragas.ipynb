# %%
# !pip install langchain_community
# !pip install ragas
# !pip install --upgrade google-generativeai langchain
# !pip install rapidfuzz
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 36.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 53.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.2/411.2 kB 28.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 3.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.24
#     Uninstalling langchain-core-0.3.24:
#       Successfully uninstalled langchain-core-0.3.24
#   Attempting uninstall: langchain-text-splitters
#     Found existing installation: langchain-text-splitters 0.3.2
#     Uninstalling langchain-text-splitters-0.3.2:
#       Successfully uninstalled langchain-text-splitters-0.3.2
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.11
#     Uninstalling langchain-0.3.11:
#       Successfully uninstalled langchain-0.3.11
# ...

# %%
# import os
# from langchain.document_loaders import TextLoader

# # Load your documents
# path = "/content/changelog.txt"
# loader = TextLoader(path)
# docs = loader.load()

# # Set your API key for Google Gemini (PaLM) here
# os.environ["GEMINI_API_KEY"] = "AIzaSyDH9DdWG8ie9_wNLPuG9vLv5c9tjNAxndk"

# import google.generativeai as genai
# genai.configure(api_key=os.environ["GEMINI_API_KEY"])

# from ragas.llms import LangchainLLMWrapper
# from ragas.embeddings import LangchainEmbeddingsWrapper
# from langchain.llms import GooglePalm
# from langchain.embeddings import GooglePalmEmbeddings
# from ragas.testset import TestsetGenerator

# # Initialize the LLM using GooglePalm with your API key and Gemini model name
# generator_llm = LangchainLLMWrapper(
#     GooglePalm(
#         google_api_key=os.environ["GEMINI_API_KEY"],
#         model_name="models/gemini-1.5-flash-8b"
#     )
# )

# # Initialize embeddings (if you have a compatible embeddings model):
# generator_embeddings = LangchainEmbeddingsWrapper(
#     GooglePalmEmbeddings(google_api_key=os.environ["GEMINI_API_KEY"])
# )

# # Generate the test set
# generator = TestsetGenerator(llm=generator_llm, embedding_model=generator_embeddings)
# dataset = generator.generate_with_langchain_docs(docs, testset_size=10)

# %%
pip install google-generativeai==0.2.2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.2/133.2 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.9/267.9 kB 15.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: google-ai-generativelanguage
#     Found existing installation: google-ai-generativelanguage 0.6.10
#     Uninstalling google-ai-generativelanguage-0.6.10:
#       Successfully uninstalled google-ai-generativelanguage-0.6.10
#   Attempting uninstall: google-generativeai
#     Found existing installation: google-generativeai 0.8.3
#     Uninstalling google-generativeai-0.8.3:
#       Successfully uninstalled google-generativeai-0.8.3
# ...

# %%
from langchain.chat_models import ChatGooglePalm
from ragas.llms import LangchainLLMWrapper
from ragas.embeddings import LangchainEmbeddingsWrapper
from langchain.embeddings import GooglePalmEmbeddings
from ragas.testset import TestsetGenerator
import os

# Set your GEMINI_API_KEY environment variable
os.environ["GEMINI_API_KEY"] = "AIzaSyDH9DdWG8ie9_wNLPuG9vLv5c9tjNAxndk"

generator_llm = LangchainLLMWrapper(
    ChatGooglePalm(
        google_api_key=os.environ["GEMINI_API_KEY"],
        model_name="models/gemini-1.5-flash-8b"  # Confirm this model name is correct
    )
)

# If embeddings using GooglePalm are supported, use them:
generator_embeddings = LangchainEmbeddingsWrapper(
    GooglePalmEmbeddings(
        google_api_key=os.environ["GEMINI_API_KEY"]
    )
)

# Load your document (e.g., TextLoader for a single .txt file)
from langchain.document_loaders import TextLoader
loader = TextLoader("/content/changelog.txt")
docs = loader.load()

# Generate the test set
generator = TestsetGenerator(llm=generator_llm, embedding_model=generator_embeddings)
dataset = generator.generate_with_langchain_docs(docs, testset_size=10)
# Out:
# Applying HeadlinesExtractor:   0%|          | 0/1 [00:00<?, ?it/s]
# WARNING:langchain_community.chat_models.google_palm:Retrying langchain_community.chat_models.google_palm.achat_with_retry.<locals>._achat_with_retry in 2.0 seconds as it raised BadRequest: 400 POST https://generativelanguage.googleapis.com/v1beta3/models/gemini-1.5-flash-8b:generateMessage?%24alt=json%3Benum-encoding%3Dint: Request payload size exceeds the limit: 20000 bytes..
# WARNING:tornado.access:400 POST /v1beta3/models/gemini-1.5-flash-8b:generateMessage?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 586.89ms
# WARNING:tornado.access:400 POST /v1beta3/models/gemini-1.5-flash-8b:generateMessage?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 305.92ms
# ...

# %%
import os
from langchain.chat_models import ChatGooglePalm
from ragas.llms import LangchainLLMWrapper
from ragas.embeddings import LangchainEmbeddingsWrapper
from langchain.embeddings import GooglePalmEmbeddings
from ragas.testset import TestsetGenerator
from langchain.document_loaders import TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.docstore.document import Document

# Set your GEMINI_API_KEY environment variable
os.environ["GEMINI_API_KEY"] = "AIzaSyDH9DdWG8ie9_wNLPuG9vLv5c9tjNAxndk"

# Initialize the LLM using ChatGooglePalm and your Gemini model
generator_llm = LangchainLLMWrapper(
    ChatGooglePalm(
        google_api_key=os.environ["GEMINI_API_KEY"],
        model_name="models/gemini-1.5-flash-8b"  # Ensure this model name is correct
    )
)

# Initialize embeddings using GooglePalmEmbeddings
generator_embeddings = LangchainEmbeddingsWrapper(
    GooglePalmEmbeddings(
        google_api_key=os.environ["GEMINI_API_KEY"]
    )
)

# Load your document (e.g., from a .txt file)
loader = TextLoader("/content/changelog.txt")
docs = loader.load()

# Split the documents into smaller chunks to avoid large payloads
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=2000,    # Adjust as needed
    chunk_overlap=200   # Adjust overlap as needed
)

split_docs = []
for doc in docs:
    chunks = text_splitter.split_text(doc.page_content)
    for chunk in chunks:
        split_docs.append(Document(page_content=chunk, metadata=doc.metadata))

# Generate the test set using the smaller chunked documents
generator = TestsetGenerator(llm=generator_llm, embedding_model=generator_embeddings)
dataset = generator.generate_with_langchain_docs(split_docs, testset_size=10)

print("Dataset generated successfully!")
